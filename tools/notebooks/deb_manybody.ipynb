# %%
from ase.io.trajectory import Trajectory
from irff.deb.theta import theta
from irff.deb.deb_bde import deb_energy,deb_bo,get_changed_fourboday,get_changed_threeboday
from irff.irff_np import IRFF_NP

# %%
images = Trajectory('md.traj')

# %%
get_changed_fourboday(images=images)
# Out:
# O-N-N-C (3, 1, 2, 4) 0.3214724986888309

# %%
get_changed_threeboday(images=images[0:20])
# Out:
# C-N-N (4, 15, 14) 0.11065533914308134

# %%
images = Trajectory('md.traj')
e = deb_energy(images,show=True)

# %%
get_changed_fourboday(images=images)
# Out:
# C-N-N-O (1, 15, 13, 21) 0.05820531056396949

# %%
images_hmx1 = Trajectory('md-hmx1.traj')
e = deb_energy(images_hmx1,show=True)

# %%
get_changed_threeboday(images=images_hmx1)
# Out:
# C-N-N (0, 16, 18) 0.2243013434221248

# %%
images_c3h5= Trajectory('md-c3h5.traj')
e = deb_energy(images_c3h5,show=True)

# %%
images= Trajectory('md-fox.traj')
e = deb_energy(images,show=True)

# %%
get_changed_fourboday(images=images)
# Out:
# O-N-C-C (1, 4, 6, 7) 0.6826295042534142

# %%
images = Trajectory('md.traj')
e = deb_energy(images,show=True)

# %%
get_changed_threeboday(images=images)
# Out:
# C-C-C (1, 2, 14) 0.03843218442684655

# %%
get_changed_fourboday(images=images)
# Out:
# C-C-N-O (0, 1, 6, 7) 0.1638981797548831

# %%
images = Trajectory('c3h8-bend.traj')
e = deb_energy(images,show=True)

# %%
get_changed_fourboday(images=images)
# Out:
# H-C-C-H (3, 1, 7, 10) 0.20623387693181647

# %%
get_changed_threeboday(images=images)
# Out:
# C-C-C (0, 1, 7) 0.6118696094552478

# %%
images = Trajectory('md-c3h5.traj')
deb_bo(images,i=0,j=1,print_=True,show=True,delta=True,x_distance=True)
# Out:
# -  rcut bo: 2.3
#   0  r: 1.0680 Di: 5.6856 Dj: 0.0163 bo0: 2.9020 bo1: 1.1920 e: -3.426242
#   1  r: 1.0510 Di: 5.6560 Dj: 0.0163 bo0: 2.9143 bo1: 1.1908 e: -3.483799
#   2  r: 1.0444 Di: 5.6278 Dj: 0.0134 bo0: 2.9187 bo1: 1.1962 e: -3.505771
#   3  r: 1.0483 Di: 5.6043 Dj: 0.0090 bo0: 2.9161 bo1: 1.2054 e: -3.483839
#   4  r: 1.0551 Di: 5.5812 Dj: 0.0058 bo0: 2.9114 bo1: 1.2121 e: -3.440619
#   5  r: 1.0608 Di: 5.5566 Dj: 0.0039 bo0: 2.9073 bo1: 1.2151 e: -3.402714
#   6  r: 1.0655 Di: 5.5319 Dj: 0.0028 bo0: 2.9039 bo1: 1.2161 e: -3.372904
#   7  r: 1.0697 Di: 5.5103 Dj: 0.0021 bo0: 2.9007 bo1: 1.2161 e: -3.347226
#   8  r: 1.0737 Di: 5.4966 Dj: 0.0017 bo0: 2.8975 bo1: 1.2160 e: -3.324793
#   9  r: 1.0770 Di: 5.4955 Dj: 0.0015 bo0: 2.8949 bo1: 1.2161 e: -3.308687
#  10  r: 1.0788 Di: 5.5108 Dj: 0.0016 bo0: 2.8934 bo1: 1.2168 e: -3.303061
#  11  r: 1.0783 Di: 5.5437 Dj: 0.0020 bo0: 2.8939 bo1: 1.2185 e: -3.311232
